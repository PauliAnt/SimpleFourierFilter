# %%
from SimpleFourierFilter import spectralDensity, fourierFilter
import numpy as np
import matplotlib.pyplot as plt

# Data generation
N = 101
e = np.random.normal(size=(N))
t = np.linspace(0,1,N)
f = np.sin(10*t)
X = f+e

X_new = fourierFilter(X,ratio=0.2,method="lowpass",plotting="both")
